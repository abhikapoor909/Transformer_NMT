# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/language-translation-englishfrench/eng_-french.csv

# %%
seed=42

# %%
data_path = '/kaggle/input/language-translation-englishfrench/eng_-french.csv'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from torch.utils.data import Dataset, DataLoader, Subset
import pandas as pd
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Install nltk if not already installed (e.g., in Colab)
# Uncomment the following lines if running in Colab
# !pip install nltk
nltk.download('punkt')

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Vocabulary class
class Vocabulary:
    def __init__(self):
        self.word2idx = {"<pad>": 0, "<sos>": 1, "<eos>": 2, "<unk>": 3}
        self.idx2word = {0: "<pad>", 1: "<sos>", 2: "<eos>", 3: "<unk>"}
        self.n_words = 4

    def add_sentence(self, sentence):
        for word in sentence.lower().split():
            if word not in self.word2idx:
                self.word2idx[word] = self.n_words
                self.idx2word[self.n_words] = word
                self.n_words += 1

# Dataset class with truncation
class TranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, max_seq_len=100):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.max_seq_len = max_seq_len
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        src_sentence = self.data.iloc[idx]['en'].lower().split()
        tgt_sentence = self.data.iloc[idx]['fr'].lower().split()
        
        src_tokens = [self.src_vocab.word2idx['<sos>']] + \
                     [self.src_vocab.word2idx.get(word, self.src_vocab.word2idx['<unk>']) for word in src_sentence[:self.max_seq_len-2]] + \
                     [self.src_vocab.word2idx['<eos>']]
        tgt_tokens = [self.tgt_vocab.word2idx['<sos>']] + \
                     [self.tgt_vocab.word2idx.get(word, self.tgt_vocab.word2idx['<unk>']) for word in tgt_sentence[:self.max_seq_len-2]] + \
                     [self.tgt_vocab.word2idx['<eos>']]
        
        return torch.tensor(src_tokens), torch.tensor(tgt_tokens)

# Collate function with padding
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)
    src_batch = nn.utils.rnn.pad_sequence(src_batch, padding_value=0)
    tgt_batch = nn.utils.rnn.pad_sequence(tgt_batch, padding_value=0)
    return src_batch, tgt_batch

# Multi-Head Attention
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        
        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.W_O = nn.Linear(d_model, d_model)
    
    def forward(self, query, key, value, mask=None):
        batch_size = query.size(0)
        query = self.W_Q(query).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        key = self.W_K(key).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        value = self.W_V(value).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        
        scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        p_attn = F.softmax(scores, dim=-1)
        attended = torch.matmul(p_attn, value)
        attended = attended.transpose(1, 2).contiguous().view(batch_size, -1, self.d_model)
        output = self.W_O(attended)
        return output

# Encoder Layer
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout=0.1):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# Decoder Layer
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout=0.1):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=100):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x

# Transformer Model
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model=512, num_heads=8, num_layers=6, d_ff=2048, max_seq_len=100, dropout=0.1):
        super(Transformer, self).__init__()
        self.src_embedding = nn.Embedding(src_vocab_size, d_model)
        self.tgt_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_len)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)
    
    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)
        seq_length = tgt.size(1)
        nopeak_mask = (1 - torch.triu(torch.ones(1, seq_length, seq_length), diagonal=1)).bool().to(device)
        tgt_mask = tgt_mask & nopeak_mask
        return src_mask, tgt_mask
    
    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.src_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.tgt_embedding(tgt)))
        
        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)
        
        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)
        
        output = self.fc(dec_output)
        return output

# Greedy decoding function for inference
def greedy_decode(model, src, tgt_vocab, max_len=100):
    model.eval()
    src = src.to(device)
    batch_size = src.size(0)
    with torch.no_grad():
        src_mask, _ = model.generate_mask(src, torch.zeros(batch_size, 1).long().to(device))
        src_embedded = model.positional_encoding(model.src_embedding(src))
        enc_output = src_embedded
        for enc_layer in model.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)
        
        tgt = torch.tensor([[tgt_vocab.word2idx['<sos>']]] * batch_size, dtype=torch.long).to(device)
        for _ in range(max_len):
            tgt_mask = model.generate_mask(src, tgt)[1]
            tgt_embedded = model.positional_encoding(model.tgt_embedding(tgt))
            dec_output = tgt_embedded
            for dec_layer in model.decoder_layers:
                dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)
            output = model.fc(dec_output)
            next_word = output[:, -1, :].argmax(dim=-1).unsqueeze(1)
            tgt = torch.cat([tgt, next_word], dim=1)
            if next_word.item() == tgt_vocab.word2idx['<eos>']:
                break
    translated = [tgt_vocab.idx2word[idx.item()] for idx in tgt[0]]
    return ' '.join(translated[1:])

# BLEU evaluation function with smoothing
def evaluate_bleu(model, test_loader, src_vocab, tgt_vocab):
    model.eval()
    bleu_scores = []
    smoothing = SmoothingFunction().method1  # Use smoothing to handle zero n-gram counts
    with torch.no_grad():
        for src, tgt in test_loader:
            src = src.transpose(0, 1).to(device)
            tgt = tgt.transpose(0, 1).to(device)
            for i in range(src.size(0)):
                src_input = src[i:i+1]
                ref_tokens = tgt[i].tolist()
                ref_text = ' '.join([tgt_vocab.idx2word[t] for t in ref_tokens if t not in [0, tgt_vocab.word2idx['<sos>'], tgt_vocab.word2idx['<eos>']]])
                pred_text = greedy_decode(model, src_input, tgt_vocab)
                ref_words = ref_text.split()
                pred_words = pred_text.split()
                bleu = sentence_bleu([ref_words], pred_words, smoothing_function=smoothing)
                bleu_scores.append(bleu)
                
                # Debug: Print first 5 translations per epoch to check quality
                if i < 5:
                    print(f"Reference: {ref_text}")
                    print(f"Predicted: {pred_text}")
                    print(f"BLEU for this pair: {bleu:.4f}\n")
    return sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0.0

# Load and prepare data
data = pd.read_csv(data_path)
data = data.sample(n=25000, random_state=42)
data.columns = ['en', 'fr']

src_vocab = Vocabulary()
tgt_vocab = Vocabulary()
for row in data.itertuples():
    src_vocab.add_sentence(row.en)
    tgt_vocab.add_sentence(row.fr)

# Split dataset into train and test
dataset = TranslationDataset(data, src_vocab, tgt_vocab, max_seq_len=100)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = Subset(dataset, range(train_size)), Subset(dataset, range(train_size, len(dataset)))
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, collate_fn=collate_fn)

# Model parameters
src_vocab_size = src_vocab.n_words
tgt_vocab_size = tgt_vocab.n_words
d_model = 512
num_heads = 8
num_layers = 6
d_ff = 2048
max_seq_len = 100
dropout = 0.1

# Initialize model
model = Transformer(src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_len, dropout).to(device)
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 25
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    num_batches = len(train_loader)
    print(f"\nStarting Epoch {epoch+1}/{num_epochs} with {num_batches} batches")
    
    for batch_idx, (src, tgt) in enumerate(train_loader):
        src = src.transpose(0, 1).to(device)
        tgt = tgt.transpose(0, 1).to(device)
        tgt_input = tgt[:, :-1]
        tgt_output = tgt[:, 1:]
        
        optimizer.zero_grad()
        output = model(src, tgt_input)
        loss = criterion(output.reshape(-1, tgt_vocab_size), tgt_output.reshape(-1))
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx+1}/{num_batches}, Loss: {loss.item():.4f}")
    
    avg_loss = total_loss / num_batches
    print(f"Epoch {epoch+1}/{num_epochs} Completed, Average Loss: {avg_loss:.4f}")
    



# Evaluate BLEU on test set after each epoch
bleu_score = evaluate_bleu(model, test_loader, src_vocab, tgt_vocab)
print(f"Epoch {epoch+1}/{num_epochs}, BLEU Score: {bleu_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Epoch 4/25, Batch 252/313, Loss: 2.7434
# Epoch 4/25, Batch 253/313, Loss: 2.6268
# Epoch 4/25, Batch 254/313, Loss: 2.7595
# Epoch 4/25, Batch 255/313, Loss: 2.7130
# Epoch 4/25, Batch 256/313, Loss: 2.4843
# Epoch 4/25, Batch 257/313, Loss: 2.8069
# Epoch 4/25, Batch 258/313, Loss: 2.6282
# Epoch 4/25, Batch 259/313, Loss: 2.7925
# Epoch 4/25, Batch 260/313, Loss: 3.0216
# Epoch 4/25, Batch 261/313, Loss: 2.8788
# ...
# Predicted: je vous suis reconnaissant de me rendre à la fête. <eos>
# BLEU for this pair: 0.1631
#
# Reference: pourquoi ne me laisses-tu pas te conter ce qui est arrivé ?
# Predicted: pourquoi ne me dites-vous pas ce que tu as passé ? <eos>
# BLEU for this pair: 0.1003
#
# Reference: dites-moi ce que tom a pris avec lui.
# Predicted: dites-moi ce que tom a pris de lui. <eos>
# BLEU for this pair: 0.6105
#
# Reference: je suppose que cela ne me regarde pas.
# Predicted: j'imagine que ça ne me brise pas tomber. <eos>
# BLEU for this pair: 0.0561
#
# Reference: pouvez-vous m'indiquer où se trouve l'entrée du métro ?
# Predicted: peux-tu me dire où le plus heureux de la plus grande ? <eos>
# BLEU for this pair: 0.0185
#
# Reference: c'est un beau travers de porc.
# Predicted: c'est un chouette de ces histoires <eos>
# BLEU for this pair: 0.0773
#
# Reference: tu ne connais pas la vérité.
# Predicted: tu ne connais pas la vérité. <eos>
# BLEU for this pair: 0.8091
#
# Reference: je vous aime tous les deux.
# Predicted: j'adore toutes les deux. <eos>
# BLEU for this pair: 0.0930
#
# Reference: on m'a dit que tu étais un expert.
# Predicted: vous lui dit que vous étiez membre. <eos>
# BLEU for this pair: 0.0587
#
# Reference: sors de ma chambre !
# Predicted: sortez de ma chambre ! <eos>
# BLEU for this pair: 0.5081
#
# Reference: j'ai dû faire mon devoir.
# Predicted: je devais faire des devoir. <eos>
# BLEU for this pair: 0.0485
#
# Reference: les classes commenceront demain.
# Predicted: les avance demain. <eos>
# BLEU for this pair: 0.0955
#
# Reference: vous n'êtes pas encore adolescent.
# Predicted: tu n'es pas encore un bébé. <eos>
# BLEU for this pair: 0.0699
#
# Reference: je sais que tom est un dur à cuire.
# Predicted: je sais que tom est dur. <eos>
# BLEU for this pair: 0.4620
#
# Reference: je savais que cela allait être une aventure.
# Predicted: je savais que ce serait une usine <eos>
# BLEU for this pair: 0.1477
#
# Reference: qu'est-ce que tu fais lundi ?
# Predicted: qu'es-tu en train de faire ? <eos>
# BLEU for this pair: 0.0330
#
# Reference: y a-t-il beaucoup de fleurs dans le jardin ?
# Predicted: y a-t-il de fleurs dans la plus ? <eos>
# BLEU for this pair: 0.1562
#
# Reference: plus n'est pas toujours mieux.
# Predicted: plus de ne pas toujours un avantage. <eos>
# BLEU for this pair: 0.0650
#
# Reference: pourquoi est-ce que je vous cause, d'abord ?
# Predicted: pourquoi est-ce que je te dis quoi que ce soit ? <eos>
# BLEU for this pair: 0.2242
#
# Reference: pourquoi ne m'avez-vous pas dit cela plus tôt ?
# Predicted: pourquoi ne m'as-tu pas dit cela plus tôt ? <eos>
# BLEU for this pair: 0.5814
#
# Reference: je n'ai pas obtenu l'emploi.
# Predicted: je n'ai pas fait le travail. <eos>
# BLEU for this pair: 0.1635
#
# Reference: ils affirmèrent que c'était vrai.
# Predicted: ils ont fait ça que c'était vrai. <eos>
# BLEU for this pair: 0.1477
#
# Reference: elle dansa avec joie.
# Predicted: elle a dansé avec ça. <eos>
# BLEU for this pair: 0.0485
#
# Reference: nous savons que tu es malade.
# Predicted: nous savons que vous êtes malade. <eos>
# BLEU for this pair: 0.1757
#
# Reference: tom a-t-il laissé un message ?
# Predicted: tom a-t-il laissé un message ? <eos>
# BLEU for this pair: 0.8091
#
# Reference: vous allez être sur pieds.
# Predicted: tu vas être sur pieds. <eos>
# BLEU for this pair: 0.2021
#
# Reference: les murs étaient couverts de graffitis.
# Predicted: les murs étaient partis. <eos>
# BLEU for this pair: 0.2177
#
# Reference: je cherche ma clé.
# Predicted: je cherche ma clé. <eos>
# BLEU for this pair: 0.6687
#
# Reference: tom dit qu'il aime bien l'idée.
# Predicted: tom dit qu'il aime cette idée. <eos>
# BLEU for this pair: 0.4111
#
# Reference: ce n'est vraiment plus nécessaire.
# Predicted: ce n'est pas vraiment nécessaire que les mathématiques. <eos>
# BLEU for this pair: 0.0561
#
# Reference: chaque pièce a été minutieusement fouillée.
# Predicted: chaque pièce était complètement le français. <eos>
# BLEU for this pair: 0.0699
#
# Reference: il parle le russe.
# Predicted: il parle du russe. <eos>
# BLEU for this pair: 0.1257
#
# Reference: tom est un garçon honnête.
# Predicted: tom est un nom de la type. <eos>
# BLEU for this pair: 0.1375
#
# Reference: tom a ton âge.
# Predicted: tom est ton âge. <eos>
# BLEU for this pair: 0.1257
#
# Reference: j'espère que vous cesserez de me raconter des mensonges.
# Predicted: j'espère que vous vous vous vous vous arrêterez de me raconter des mensonges. <eos>
# BLEU for this pair: 0.3556
#
# Reference: pourquoi êtes-vous venue ici aujourd'hui ?
# Predicted: pourquoi es-tu venue ici aujourd'hui ? <eos>
# BLEU for this pair: 0.4347
#
# Reference: puis-je vous servir un verre ?
# Predicted: puis-je te faire un verre ? <eos>
# BLEU for this pair: 0.1757
#
# Reference: parlez-nous-en !
# Predicted: parle-nous tous les tous. <eos>
# BLEU for this pair: 0.0000
#
# Reference: nous sommes allés à boston.
# Predicted: nous nous sommes allés à boston. <eos>
# BLEU for this pair: 0.6148
#
# Reference: pourquoi es-tu si inquiet ?
# Predicted: pourquoi êtes-vous si occupées ? <eos>
# BLEU for this pair: 0.0537
#
# Reference: je pensais que tu étais plus âgée que moi.
# Predicted: je pensais que vous étiez plus âgé que moi. <eos>
# BLEU for this pair: 0.1375
#
# Reference: laisse-moi en être juge.
# Predicted: laissez-moi être la plus grande de ça. <eos>
# BLEU for this pair: 0.0278
#
# Reference: je ne suis pas sûr que ce soit une bonne idée.
# Predicted: je ne suis pas sûre que ceci soit une bonne idée. <eos>
# BLEU for this pair: 0.4367
#
# Reference: l'arbre bloqua la route.
# Predicted: l'arbre a battu la route. <eos>
# BLEU for this pair: 0.0955
#
# Reference: étiez-vous à la bibliothèque hier après-midi?
# Predicted: étiez-vous au tennis hier soir ? <eos>
# BLEU for this pair: 0.0393
#
# Reference: j'ai envisagé de changer d'emploi.
# Predicted: j'ai considéré à ma travail ! <eos>
# BLEU for this pair: 0.0330
#
# Reference: j'en rêve depuis que je suis enfant.
# Predicted: j'ai rêvé de mal depuis un enfant. <eos>
# BLEU for this pair: 0.0330
#
# Reference: je veux juste savoir dans quoi je mets les pieds.
# Predicted: je veux juste savoir ce que je vais en train de dire. <eos>
# BLEU for this pair: 0.2045
#
# Reference: as-tu parlé à tom hier ?
# Predicted: avez-vous parlé hier ? <eos>
# BLEU for this pair: 0.1029
#
# Reference: qui devons-nous croire?
# Predicted: qui devrait croire ? <eos>
# BLEU for this pair: 0.0537
#
# Reference: elle n'a pas voulu qu'il jouât au poker.
# Predicted: elle ne voulut pas qu'il joue de jouer aux autres. <eos>
# BLEU for this pair: 0.0248
#
# Reference: j'espère que tu es également heureux.
# Predicted: j'espère que vous êtes en train de chanter <eos>
# BLEU for this pair: 0.0507
#
# Reference: ils forment le dessus du panier.
# Predicted: ils sont en train de poster <eos>
# BLEU for this pair: 0.0330
#
# Reference: je vais la faire demain.
# Predicted: je le ferai demain. <eos>
# BLEU for this pair: 0.0639
#
# Reference: elle me dit qu'elle avait des choses plus importantes sur le feu.
# Predicted: elle me dit qu'elle avait plus tôt pour réclamer en tête. <eos>
# BLEU for this pair: 0.3318
#
# Reference: ça ne vous a pas réussi.
# Predicted: ça ne t'a pas réussi. <eos>
# BLEU for this pair: 0.1221
#
# Reference: j'ai égaré mon parapluie.
# Predicted: j'ai perdu mon parapluie. <eos>
# BLEU for this pair: 0.1257
#
# Reference: c'est un homme très bien payé.
# Predicted: c'est un homme hautement homme. <eos>
# BLEU for this pair: 0.2021
#
# Reference: notre professeur paraît jeune pour son âge.
# Predicted: notre professeur de son jeune âge. <eos>
# BLEU for this pair: 0.0878
#
# Reference: tom a emmené mary à l'hôpital.
# Predicted: tom alla à mary de l'hôpital. <eos>
# BLEU for this pair: 0.0467
#
# Reference: ce pantalon me va bien.
# Predicted: ces livres me rend bien. <eos>
# BLEU for this pair: 0.0485
#
# Reference: personne ne se douta de rien.
# Predicted: personne n'a rien dit. <eos>
# BLEU for this pair: 0.0440
#
# Reference: elle n'a pas besoin d'y aller en personne.
# Predicted: elle n'a pas besoin de s'y rendre en personne. <eos>
# BLEU for this pair: 0.3124
#
# Reference: mon idée est assez différente de la vôtre.
# Predicted: mon idée est assez différente de la tienne. <eos>
# BLEU for this pair: 0.7260
#
# Reference: avez-vous jamais triché à un examen ?
# Predicted: as-tu jamais trompé sur une petite amie ? <eos>
# BLEU for this pair: 0.0285
#
# Reference: je veux que vous preniez ceci avec vous.
# Predicted: je veux que tu regardes avec toi. <eos>
# BLEU for this pair: 0.1477
#
# Reference: es-tu capable de nager correctement ?
# Predicted: as-tu le nager plus de nager ? <eos>
# BLEU for this pair: 0.0650
#
# Reference: je voulais rester à la maison.
# Predicted: je voulais rester chez moi. <eos>
# BLEU for this pair: 0.2021
#
# Reference: je te dois de sincères excuses.
# Predicted: je te dois une photo de la tête. <eos>
# BLEU for this pair: 0.1275
#
# Reference: passes-tu davantage de temps avec tes amies ou avec ta famille ?
# Predicted: passes-tu davantage de temps avec tes amies ou votre famille ? <eos>
# BLEU for this pair: 0.6704
#
# Reference: y a-t-il quelque chose que vous ignoriez ?
# Predicted: y a-t-il quoi que ce soit que vous n'y êtes pas ? <eos>
# BLEU for this pair: 0.0491
#
# Reference: je ne dis rien, ce qui le rendit plus furieux.
# Predicted: j'ai dit à lui passer plus de temps en déjeuner. <eos>
# BLEU for this pair: 0.0189
#
# Reference: une fois que vous avez commencé quelque chose, n'abandonnez pas.
# Predicted: une fois que vous n'avez pas commencé il ne le donnerai <eos>
# BLEU for this pair: 0.2242
#
# Reference: je ne me suis pas sentie si heureuse depuis longtemps.
# Predicted: je ne me sentais pas cette heureux depuis bien longtemps. <eos>
# BLEU for this pair: 0.1109
#
# Reference: la cuisine était propre.
# Predicted: la cuisine était net. <eos>
# BLEU for this pair: 0.2659
#
# Reference: ce pantalon a besoin d'être repassé.
# Predicted: ces photos a besoin de neuf ? <eos>
# BLEU for this pair: 0.0587
#
# Reference: est-ce que tu as trouvé une quelconque bonne solution ?
# Predicted: as-tu trouvé une bonne solution ? <eos>
# BLEU for this pair: 0.1339
#
# Reference: j'ai déjà fait la portion difficile.
# Predicted: j'ai déjà fait passer les phares. <eos>
# BLEU for this pair: 0.1635
#
# Reference: j'aimerais une chambre.
# Predicted: j'aimerais de chambre. <eos>
# BLEU for this pair: 0.0955
#
# Reference: je voulais faire ça.
# Predicted: je voulais faire ça. <eos>
# BLEU for this pair: 0.6687
#
# Reference: vous étiez supposés faire cela hier.
# Predicted: tu étais censé faire ça hier. <eos>
# BLEU for this pair: 0.0393
#
# Reference: où veux-tu en venir ?
# Predicted: à quoi ricanez-vous ? <eos>
# BLEU for this pair: 0.0537
#
# Reference: laissez-moi vous le porter.
# Predicted: laissez-moi vous la porter. <eos>
# BLEU for this pair: 0.1257
#
# Reference: tes parents parlent-ils français ?
# Predicted: tes parents parle français ? <eos>
# BLEU for this pair: 0.1221
#
# Reference: le garçon appuya sa tête contre la vitrine du magasin.
# Predicted: le garçon rendait ses dents dans le magasin de la fenêtre. <eos>
# BLEU for this pair: 0.0399
#
# Reference: quelles langues parle-t-on en belgique ?
# Predicted: qu'est-ce qu'elles t'ont parler en train de parler ? <eos>
# BLEU for this pair: 0.0251
#
# Reference: je me sens déprimé parce qu'il y a de nombreuses choses que je doive faire.
# Predicted: je me sens à cause de parce que les choses y ait de faire. <eos>
# BLEU for this pair: 0.0861
#
# Reference: où vous êtes-vous procuré toutes ces clés ?
# Predicted: où as-tu eu tout ces livres ? <eos>
# BLEU for this pair: 0.0366
#
# Reference: la souris fut attirée dans le piège à l'aide d'un gros morceau de fromage.
# Predicted: la tente n'était en mission dans une grande société à côté de la plus éloignée de la plus grande barrière <eos>
# BLEU for this pair: 0.0129
#
# Reference: je sais que vous êtes également occupées.
# Predicted: je sais que vous êtes occupés <eos>
# BLEU for this pair: 0.6148
#
# Reference: il l'a mangé en peu de temps.
# Predicted: il l'a mangé en temps. <eos>
# BLEU for this pair: 0.4548
#
# Reference: je vous aiderai à faire cela.
# Predicted: je t'aiderai à faire ça. <eos>
# BLEU for this pair: 0.0955
#
# Reference: y aller seul présente un danger.
# Predicted: c'est dangereux de s'y rendre seul. <eos>
# BLEU for this pair: 0.0000
#
# Reference: tom a rejoint notre groupe.
# Predicted: tom fit notre groupe. <eos>
# BLEU for this pair: 0.1257
#
# Reference: je suis désolée, je ne t'ai pas entendue.
# Predicted: je suis désolé, je ne vous ai pas entendues. <eos>
# BLEU for this pair: 0.0667
#
# Reference: il est en congé, aujourd'hui.
# Predicted: il est en train aujourd'hui. <eos>
# BLEU for this pair: 0.2171
#
# Reference: c'est d'accord si je fais une pause ?
# Predicted: est-ce que je crois si je prends une pause ? <eos>
# BLEU for this pair: 0.1173
#
# Reference: pourquoi devons-nous le faire ?
# Predicted: pourquoi nous devons le faire ? <eos>
# BLEU for this pair: 0.1757
#
# Reference: nous nous sommes perdus de vue.
# Predicted: nous nous sommes perdu de les uns des autres. <eos>
# BLEU for this pair: 0.1122
#
# Reference: j'avais envie de dormir.
# Predicted: j'ai été sommeil. <eos>
# BLEU for this pair: 0.0000
#
# Reference: ce n'est pas assez bien pour toi.
# Predicted: ce n'est pas assez bon pour toi. <eos>
# BLEU for this pair: 0.4111
#
# Reference: j'irai où vous voulez.
# Predicted: je vais te rendre où tu veux. <eos>
# BLEU for this pair: 0.0278
#
# Reference: c'est fou de ta part de nager quand il fait si froid.
# Predicted: il vous fait perdre de nager quand il est froid. <eos>
# BLEU for this pair: 0.2371
#
# Reference: j'ai pleuré.
# Predicted: j'ai pleuré. <eos>
# BLEU for this pair: 0.2403
#
# Reference: tom a dit qu'il était effrayé.
# Predicted: tom a dit qu'il était effrayé. <eos>
# BLEU for this pair: 0.8091
#
# Reference: j'ai acheté le livre pour dix dollars.
# Predicted: j'ai acheté le livre pour dix dollars. <eos>
# BLEU for this pair: 0.8409
#
# Reference: je suis né en amérique.
# Predicted: je suis née en amérique. <eos>
# BLEU for this pair: 0.1221
#
# Reference: la pomme est rouge.
# Predicted: le pomme est rouge. <eos>
# BLEU for this pair: 0.2659
#
# Reference: choisissez-en une parmi ceux-là.
# Predicted: choisissez l'un de chez lui ! <eos>
# BLEU for this pair: 0.0000
#
# Reference: certains grands oiseaux chassent les petits et des animaux.
# Predicted: certains de oiseaux sur le petit ami et la plus riches <eos>
# BLEU for this pair: 0.0224
#
# Reference: tom a mangé de la nourriture avariée et est tombé malade.
# Predicted: tom a mangé quelques restes et moi malade. <eos>
# BLEU for this pair: 0.1080
#
# Reference: à quelle heure veux-tu que je sois là ?
# Predicted: à quelle heure veux-tu que je sois ici ? <eos>
# BLEU for this pair: 0.6606
#
# Reference: grimpe dans la camionnette !
# Predicted: monte dans le placard. <eos>
# BLEU for this pair: 0.0537
#
# Reference: il y a beaucoup de meubles dans cette pièce.
# Predicted: il y a beaucoup de meubles dans cette pièce. <eos>
# BLEU for this pair: 0.8801
#
# Reference: j'adore regarder des films qui me donnent à réfléchir.
# Predicted: j'adore regarder des films qui me font réfléchir. <eos>
# BLEU for this pair: 0.6105
#
# Reference: les femmes ont certes aujourd'hui davantage de droits. mais elles avaient auparavant davantage de pouvoir.
# Predicted: c'est vrai que les femmes plus tard avant de la semaine avant plus précieux. <eos>
# BLEU for this pair: 0.0309
#
# Reference: la seule chose qui compte vraiment est si oui ou non tu as fait de ton mieux.
# Predicted: la seule chose qui importe est que votre vélo ne soit pas soit en train <eos>
# BLEU for this pair: 0.1521
#
# Reference: nous devrions utiliser le feu ouvert ce soir.
# Predicted: nous devrions utiliser le coup ce soir. <eos>
# BLEU for this pair: 0.4111
#
# Reference: les soldats pouvaient maintenant le voir.
# Predicted: les soldats lui voir maintenant. <eos>
# BLEU for this pair: 0.0863
#
# Reference: avec qui crois-tu qu'elle vit ?
# Predicted: avec qui croyez-vous être allés ? <eos>
# BLEU for this pair: 0.0773
#
# Reference: vous et moi avons quelque chose en commun.
# Predicted: vous et vous avez quelque chose en commun. <eos>
# BLEU for this pair: 0.3549
#
# Reference: je me sens impuissante.
# Predicted: je me sens impuissant. <eos>
# BLEU for this pair: 0.2659
#
# Reference: je ne connais pas la raison de son absence.
# Predicted: je ne sais pas pourquoi il était en train de se produire <eos>
# BLEU for this pair: 0.0391
#
# Epoch 25/25, BLEU Score: 0.1909

# %%
def translate_sentence(model, sentence, src_vocab, tgt_vocab, max_len=100):
    model.eval()
    tokens = [src_vocab.word2idx['<sos>']] + \
             [src_vocab.word2idx.get(word, src_vocab.word2idx['<unk>']) for word in sentence.lower().split()] + \
             [src_vocab.word2idx['<eos>']]
    src = torch.tensor(tokens, dtype=torch.long).unsqueeze(0).to(device)  # (1, seq_len)
    
    with torch.no_grad():
        tgt = torch.tensor([tgt_vocab.word2idx['<sos>']], dtype=torch.long).unsqueeze(0).to(device)  # (1, 1)
        for _ in range(max_len):
            output = model(src, tgt)  # (1, tgt_seq_len, tgt_vocab_size)
            next_word_idx = output[:, -1, :].argmax(dim=-1).item()
            if next_word_idx == tgt_vocab.word2idx['<eos>']:
                break
            tgt = torch.cat([tgt, torch.tensor([[next_word_idx]], dtype=torch.long).to(device)], dim=1)
    
    translated = [tgt_vocab.idx2word[idx.item()] for idx in tgt[0]]
    return ' '.join(translated[1:])  # Skip <sos>

# Test after training
test_sentence = "how are you doing"
translation = translate_sentence(model, test_sentence, src_vocab, tgt_vocab)
print(f"Input: {test_sentence}")
print(f"Translation: {translation}")
# Out:
# Input: how are you doing
# Translation: comment faites-vous ?
